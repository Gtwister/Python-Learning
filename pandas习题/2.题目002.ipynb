# %% [markdown]
# * 使用Pandas
# * 把下方数据Dict,变成一个Series
# * 将Series输出到命令行

# %%
import pandas as pd
grades = {'语文':80,'数学':90,'英语':85,'计算机':100}

df = pd.Series(grades)
df
# Out:
# 语文      80
# 数学      90
# 英语      85
# 计算机    100
# dtype: int64
