# %% [markdown]
# * 使用Pandas
# * 把下方的数据List,变成一个Series
# * 将Series输出到命令行

# %%
import pandas as pd

courses = ['数学','语文','英语','化学']

df = pd.Series(data=courses)
df
# Out:
# 0    数学
# 1    语文
# 2    英语
# 3    化学
# dtype: object
