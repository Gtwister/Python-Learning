# %% [markdown]
# ## 进程的介绍

# %% [markdown]
# **2.1 程序中实现多任务的方式**\
# 在Python中,想要实现多任务可以使用多进程来完成

# %% [markdown]
# **2.2 进程的概念**\
# 进程是资源分配的最小单位,它是操作系统进行资源分配和调度运行的基本单位,通俗理解:一个正在运行的程序就是一个进程,例如:正在运行的QQ
