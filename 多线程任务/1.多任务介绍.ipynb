# %% [markdown]
# # 多任务介绍

# %% [markdown]
# **1.1 多任务概念**

# %% [markdown]
# 多任务是指在同一时间执行多个任务

# %% [markdown]
# **1.2 多任务的两种表现形式**
# * 并发
# * 并行

# %% [markdown]
# **1.3 并发**\
# 在一段时间内交替去执行多个任务\
# 例子：\
# 对于单核CPU处理多任务,操作系统轮流让各个任务交替执行。

# %% [markdown]
# **1.4 并行**
# 在一段时间内真正的同时一起执行多个任务
