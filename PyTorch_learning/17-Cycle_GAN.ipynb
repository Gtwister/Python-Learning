# %% [markdown]
# ### Cycle-GAN

# %% [markdown]
# 涉及四种损失函数:
# * G网络
# * D网络
# * Cycle
# * Identity

# %% [markdown]
# D网络有点特别, PatchGAN:
# * PatchGAN输出的是一个N*N的矩阵, 需要基于感受野来计算损失
# * 基于感受野在特征图上的预测效果, 和标签(也需要设置成N*N)计算损失
