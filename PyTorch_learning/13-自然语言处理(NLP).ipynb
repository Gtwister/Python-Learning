# %% [markdown]
# **自然语言处理-词向量模型-Word2Vec**

# %% [markdown]
# * 如何描述语言的特征?通常都在词的层面上来构筑特征。Word2Vec就是要把词转换成向量
# *

# %% [markdown]
# **训练数据构建**

# %% [markdown]
# * 新闻数据、小说数据、合乎说话语言逻辑都可以作为训练数据

# %% [markdown]
# **不同模型对比**

# %% [markdown]
# * Continue Back Of Words (CBOW)
# * Skipgram

# %% [markdown]
# 在进行训练过程中，如果语料库太大如何解决输出结果过多：将输入和想得到的输出都放入模型输出层，输出结果为0，1，越接近1表示两个关系越密切，成为一个二分类任务

# %% [markdown]
# 但是我的训练集中所有得到的输出标签都为1，此时需要一些负样本来对其进行抵消，一个负采样模型。s
