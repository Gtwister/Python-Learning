# %% [markdown]
# # 调色板
# * 颜色很重要
# * color_palette()能传入任何Matplotlib所支持的颜色
# * color_palette()不写参数则默认颜色
# * set_palette()设置所有图的颜色

# %%
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
sns.set(rc={'figure.figsize':(6,6)})
# Out:
# d:\Anconda\envs\Paddle_tutorial\lib\importlib\_bootstrap.py:219: RuntimeWarning: numpy.ufunc size changed, may indicate binary incompatibility. Expected 192 from C header, got 216 from PyObject
#   return f(*args, **kwds)

# %% [markdown]
# # 分类色板

# %%
current_palette = sns.color_palette()
sns.palplot(current_palette)

# %% [markdown]
# ## 圆形画板 ##
# 当你有六个以上的分类要区别时,最简单的方法就是在一个圆形的颜色空间中画出均匀间隔的颜色(这样的色调会保持亮度和饱和度不变)。这是大多数的当他们需要使用比当前默认颜色循环中设置的颜色更多时的默认方案。\
# 最常用的方法是使用hls的颜色空间,这是RGB值的一个简单转换。

# %%
sns.palplot(sns.color_palette('hls',12))

# %%
data = np.random.normal(size=(20,8))+np.arange(8)/2
sns.boxplot(data=data,palette=sns.color_palette('hls',8))
# Out:
# <AxesSubplot:>

# %% [markdown]
# **hls_palette()函数来控制颜色的亮度和饱和度**
# * l-亮度 lightness
# * s-饱和 saturation

# %%
sns.palplot(sns.hls_palette(8,l=.3,s=.8))

# %%
sns.palplot(sns.color_palette('Paired',10))##对比颜色
