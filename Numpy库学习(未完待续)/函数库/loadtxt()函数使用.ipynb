# %% [markdown]
# numpy.loadtxt()
# 参数|作用
# --|--
# fname|被读取的文件名
# dtype|指定读取之后数据的数据类型
# comments|跳过文件中指定参数开头的行
# delimiter|指定读取文件中数据的分割符
# converters|对读取数据进行预处理
# skiprows|选择跳过的行数
# usecols|指定需要读取的列
# unpack|选择是否要将数据进行向量输出
# encoding|对读取的文件进行预编码
