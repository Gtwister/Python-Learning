# %% [markdown]
# ### 魔法方法

# %% [markdown]
# 在Python中.`__xx__()`的函数叫做魔法方法,指的是具有特殊功能的函数

# %% [markdown]
# **1.体验__init__()**

# %% [markdown]
# `__init__()`方法的作用:初始化对象。

# %%
class Washer():

    # 定义__init__,添加实例属性
    def __init__(self):
        self.width = 500
        self.height = 800

    def print_info(self):
        print(f'洗衣机的宽度是{self.width}')
        print(f'洗衣机的高度是{self.height}')

haier1 = Washer()

haier1.print_info()
# Out:
# 洗衣机的宽度是500
# 洗衣机的高度是800

# %% [markdown]
# **注意：**\
#
# * `__init__()`方法,在创建一个对象时默认被调用,不需要手动调用
# * `__init__(self)`中self 参数会被py解释器主动传递过去

# %% [markdown]
# `__init__( )`传递参数

# %%
class Washer():

    # 定义__init__,添加实例属性
    def __init__(self,width,height):
        self.width = width
        self.height = height

    def print_info(self):
        print(f'洗衣机的宽度是{self.width}')
        print(f'洗衣机的高度是{self.height}')

haier1 = Washer(10,20)

haier1.print_info()
# Out:
# 洗衣机的宽度是10
# 洗衣机的高度是20

# %% [markdown]
# ## 魔法方法`__str__( )` ##

# %% [markdown]
# 当使用print输出对象时,默认打印对象的内存地址。如果定义了`__str__`方法,那么就会打印从这个方法中return的数据。

# %%
class Washer():

    # 定义__init__,添加实例属性
    def __init__(self):
        self.width = 500
        self.height = 800

    def __str__(self) -> str:
        return '这是说明书'

haier1 = Washer()

print(haier1)
# Out:
# 这是说明书

# %% [markdown]
# ## 魔法方法`__del__( )` ##

# %% [markdown]
# 当删除对象时,python解释器也会默认调用`__del__`方法。

# %%
class Washer():

    # 定义__init__,添加实例属性
    def __init__(self):
        self.width = 500
        self.height = 800

    def __del__(self):
        print('对象已经删除')

haier1 = Washer()
##结束程序的时候，会自动删除对象，也就会直接调用魔法方法del
# Out:
# 对象已经删除
