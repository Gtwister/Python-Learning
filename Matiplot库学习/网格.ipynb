# %% [markdown]
# ## 网格

# %% [markdown]
# `plt.grid(True)`

# %%
import numpy as np
import matplotlib.pyplot as plt

x = np.arange(1,100)

plt.plot(x,x)

plt.grid(color='r',linewidth='1')

plt.show()
