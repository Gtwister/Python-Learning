# %% [markdown]
# ## 调整坐标轴刻度

# %%
import numpy as np
import matplotlib.pyplot as plt

x = np.arange(1,11,1)

plt.plot(x,x)

ax=plt.gca()
ax.locator_params('y',nbins=20)##locator_params('y'(控制改变哪个坐标轴),nbins=20(控制步长大小))

plt.show()
