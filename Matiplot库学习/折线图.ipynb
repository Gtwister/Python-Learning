# %% [markdown]
# # 折线图

# %%
import numpy as np
import matplotlib.pyplot as plt

x = np.linspace(-10,10,5)
y = x**2
plt.plot(x,y)
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
index,date=np.loadtxt('./ParisHousing.csv',delimiter=',',usecols=(0,16),skiprows=1,unpack=True)

plt.plot(index,date)
plt.show()

# %% [markdown]
# plt.plot_date()\
# 识别时间变量，并以其作为横坐标、
# plt.plot_date(date,y,'-')转化为线形函数
